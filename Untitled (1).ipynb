# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\VITHYA SRI .S\\OneDrive\\Desktop\\weekly task'

# %% [markdown]
# dataframe = pd.read_csv(r"C:\\Users\\VITHYA SRI .S\\OneDrive\\Desktop\\weekly task\\zomato-data-.CSV
# print(dataframe.head())

# %% [markdown]
# dataframe = pd.read_csv(r"C:\\Users\\VITHYA SRI .S\\OneDrive\\Desktop\\weekly task\zomato data-.csv")

# %% [markdown]
# dataframe = read_csv(r"C:\\Users\\VITHYA SRI .S\\OneDrive\\Desktop\\weekly task\zomato data-.csv")

# %% [markdown]
# dataframe = pd.read_csv(r"C:\\Users\\VITHYA SRI .S\\OneDrive\\Desktop\\weekly task\zomato data-.csv")
# print(dataframe.head())

# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\VITHYA SRI .S\\OneDrive\\Desktop\\weekly task'

# %% [markdown]
# dataframe=pd.read_csv(r"C:\\Users\\VITHYA SRI .S\\OneDrive\Desktop\\weekly task\\zomato-data-.csv")
# print(dataframe.head())

# %% [markdown]
# dataframe=pd.read_csv(r"C:\\Users\\VITHYA SRI .S\\OneDrive\\Desktop\\weekly task\\zomato-data-.csv")
# print(dataframe.head())

# %% [markdown]
# dataframe=pd.read_csv("zomato data-.csv")
# print(dataframe.head())

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Untitled.ipynb', 'Zomato-data- (1).csv']

# %% [markdown]
# dataframe=pd.read_csv("zomato data-(1).csv")
# print(dataframe.head())

# %%
dataframe=pd.read_csv("Zomato-data- (1).csv")
print(dataframe.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# handledef Rate(value):
#     value=str(value).split('/')
#     value=value[0];
#     return float(value)
#
# dataframe ['rate']=dataframe['rate'].apply(handleRate)

# %% [markdown]
# def handleRate(value):
#     value=str(value).split('/')
#     value=value[0];
#     return float(value)
#
# dataframe ['rate']=dataframe['rate'].apply(handleRate)
# print(dataframe.head())

# %%
import pandas as pd

# %%
dataframe=pd.read_csv("Zomato-data- (1).csv")
print(dataframe.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
def handleRate(value):
    value=str(value).split('/')
    value=value(0)
    return float(value)

# %% [markdown]
# dataframe['rate']=
# dataframe['rate'].apply(handleRate)
# print(dataframe.head())

# %% [markdown]
# c

# %%
def handleRate(value):
    value=str(value).split('/')
    value=value[0]
    return float(value)

# %% [markdown]
# dataframe['rate']=dataframe['rate'].apply(handleRate)
# print(dataframe.head())

# %% [markdown]
# dataframe=pd.read_csv("Zomato-data- (1).csv")
# print(dataframe.head())

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\VITHYA SRI .S\\OneDrive\\Desktop\\weekly task'

# %%
dataframe=pd.read_csv("Zomato-data- (1).csv")
print(dataframe.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
def handleRate(value):
    value=str(value).split('/')
    value=value[0]
    return float(value)

# %%
dataframe['rate']=dataframe['rate'].apply(handleRate)
print(dataframe.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# dataframe['approx_cost(for two people)']=dataframe['approx_cost(for two people)'].astype(str) dataframe['approx_cost(for two people)']=dataframe['approx_cost(for two people)'].str.replace(',',") dataframe['approx_cost(for two people)']=dataframe['approx_cost(for two people)'].astype(float)

# %%
dataframe['approx_cost(for two people)'] = dataframe['approx_cost(for two people)'].astype(str)

dataframe['approx_cost(for two people)'] = dataframe['approx_cost(for two people)'].str.replace(',', '')

dataframe['approx_cost(for two people)'] = dataframe['approx_cost(for two people)'].astype(float)

# %%
dataframe.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                        800.0          Buffet
# 1                        800.0          Buffet
# 2                        800.0          Buffet
# 3                        300.0          Buffet
# 4                        600.0          Buffet

# %%
grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum()

result = pd.DataFrame({'votes': grouped_data})

plt.plot(result, c='green', marker='o')
plt.xlabel('Type of restaurant')
plt.ylabel('Votes')
plt.show()

# %%
pivot_table = dataframe.pivot_table(
    index='listed_in(type)',
    columns='online_order',
    aggfunc='size',
    fill_value=0
)

sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', fmt='d')

plt.title("Heatmap")
plt.xlabel("Online Order")
plt.ylabel("Listed In (Type)")
plt.show()

# %% [markdown]
# Conclusion: Dining restaurants primarily accept offline orders, whereas cafes primarily receive online orders. This suggests that customers prefer to place online orders for cafes rather than dining restaurants.

# %%
print("Conclusion: Dining restaurants primarily accept offline orders, whereas cafes primarily receive online orders. This suggests that customers prefer to place online orders for cafes rather than dining restaurants.")
# Out:
# Conclusion: Dining restaurants primarily accept offline orders, whereas cafes primarily receive online orders. This suggests that customers prefer to place online orders for cafes rather than dining restaurants.
